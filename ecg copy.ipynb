# %%
import torch
from torch.utils.data import Dataset, DataLoader, SubsetRandomSampler
from torch import nn
import torch.nn.functional as F
import torch.optim as optim

import pandas as pd
import numpy as np
import random

import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold

import matplotlib.pyplot as plt

# %%
from utils import *

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")

# %%
data = import_afc_data()
# Out:
# 100%|██████████| 8528/8528 [00:01<00:00, 7162.70it/s]

# %%
data_test = data[int(len(data)*0.8):]
# data_train = [x for sub in data_train for x in sub]
data_train = data[:int(len(data)*0.8)]
# data_test = [x for sub in data_test for x in sub]

# %%
labelmap = {x:i for i,x in enumerate(list(set([x[1] for x in data_train])))}

# %%
pd.Series([x[1] for x in data_train]).value_counts()
# Out:
# N    4103
# O    1925
# A     579
# ~     215
# Name: count, dtype: int64

# %%
def plotwave(x, n=1000):
    plt.plot(x[:n])

plotwave(data_train[0][0])

# %%
len(data)
# Out:
# 8528

# %%
maxes = [np.abs(x[0]).max() for x in data_train]

# %%
class WindowDataset(Dataset):
    def __init__(self, data, labelmap, threshold_length=1000, device='cpu', eval=False):
        self.eval = eval

        self.threshold_length = threshold_length

        self.data = []
        for i, (waveform, label) in enumerate(data):
            # if len(waveform) < 400:
            #     pass

            # if i > 4 and not eval:
            #     break

            ## Z-Score Normalisation https://pdf.sciencedirectassets.com/273545/1-s2.0-S1746809419X00099/1-s2.0-S1746809419304008/main.pdf?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEJD%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJGMEQCIBU0QAQMTYgfyUZnLwfd%2FvB%2F4nxRCm3RuLZtKZ7fWyjcAiAKU%2FRDCwHN4XPuvRsXqcPZzUlACrRZM82gpaiyEee74yqyBQhIEAUaDDA1OTAwMzU0Njg2NSIMx5ynckvJ3tNuWl%2FlKo8FhqrYIJYO1JDS6KYXvVVFHfcov1wUhIa4p5Aa0ULGmrhMhFOKB%2Bn3I6TYKt9UVSxDucTQM7%2FCxwh904JgSmuL1nPCVN1xxMQnCUdR1UIxVJLQQ9FwJoM%2FfTS2efo3QTIh%2BnCaqVrYICqL7Bx1pGYSl975A%2BZVrSGi2tzROPTS%2BmQx9ORlf6Tv24X1hElEpdVy%2BgbHkNrZDILTwkbfs%2FbYXIh9fO0a2jyIwpAtrUxF%2Bd%2F6%2FulVUUsY6ZR6dIObMGwqlH22Agv9nOcgMTINELGC%2BqsWUPw%2FuC1cebaTT6bI32wKSLx2w6dq%2BiHT88sYW8V74MH1GaswjpeE%2FoxEEq6WiJjJuYI9qV3SOcbRMaYJyu69EM5zkoMaKknA7NCmXPIrURD6HEX7wgQXlHrBOieXJqF%2FnsFzp2Lp19oSqcozuNIIcAEPnpKDEHppA%2BMrc2BYfiGEwVropc1Cb3mc444uFzJH7I47q39vgzzQ%2BpGSc5iYyOfGXDWbPay4qWvewT2cSI%2FF0hN7kTrehuwjQHW%2Fidfv4TO27hFTMKLA7ZDQ%2BCoSkk0f8%2F3%2FQcMSbgp50q2BdiVjUJZzgkZvDFNsrB3RzpcjNRGFV3Qb7M8hKw1w4BoUoATLLu3awMFAhDAAmNfAnGiTb301svzkZUSZ5OyQhRL1igD4pNXQPmqsbV7%2FbpdaC5TeBYz54DsEIGqO%2Fig1NA6cHql4rQyI05oHk0szh0wXaaZOOfihuUqooxdJjUfmDRZiUUochgrvVC0EGQOCe9JbyAMSbqVPqNfq1csg16UOhF%2F3RO6faYCt08EK6pi4uFDmkakv42RR09DQvDNS%2FA0vNQX%2B%2F2z2Dr%2B4bgVOoJnHAkcngZeHYwNf3aZFJDD4i7qtBjqyAW3kY3S%2BP%2BkrLVg%2FPNf4t4YTDK9EE2RkbVaIQxTcoUMqpEZEXg7ny8GL3B9MIblfUE%2Bvx3PFd6rwdB%2F6uuWTgyW82XsWvsKH2LB44WiID%2B1tHF2W7f3lf182%2Bn5AVg8qa8mRCjG6MvcKiIxD8lOsH%2BlyHsLN52k0%2BUbp1XceM15R0FHbd7lv8WjWrJbBYrUNMuTg%2B005K8siLNk8k8Oftn3aKmYPWWseHQXjhOrVFaL78%2Bk%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20240122T164545Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAQ3PHCVTYZIIXIYUV%2F20240122%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=4fbb80e266fb73d5a1b1e5faf281b2b7e46e5ec6c4427eecddee0780a75135de&hash=7c3b44aa650c599596e1a6205d0816322ae68a2826439052209fe4e9f926e465&host=68042c943591013ac2b2430a89b270f6af2c76d8dfd086a07176afe7c76c2c61&pii=S1746809419304008&tid=spdf-a7d33034-bd26-4c4a-a4d7-bcd82730d377&sid=6bb7a7de95a0754e720b928565e5b1a3a850gxrqb&type=client&tsoh=d3d3LnNjaWVuY2VkaXJlY3QuY29t&ua=1d025a565f5e50550556&rr=849944e7ad486340&cc=gb
            waveform = (waveform - waveform.mean()) / waveform.std()
            
            # waveform,b = pywt.dwt(waveform, 'db6')
            # a,b = pywt.dwt(a, 'db6')
            # a,b = pywt.dwt(a, 'db6')
            # plotwave(waveform, 200)
            # plotwave(a, 200)
            # plotwave(b, 200)

            self.data.append((torch.tensor(waveform, dtype=torch.float32, device=device), torch.tensor(labelmap[label], device=device)))
            
            # if len(data) > 4000:
            #     break

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        waveform, label = self.data[idx]

        if waveform.shape[0] < self.threshold_length:
            waveform = torch.cat((torch.tensor([0] * (self.threshold_length - waveform.shape[0]), device=device), waveform))
        else:
            startidx = random.randint(0, len(waveform) - self.threshold_length)
            waveform = waveform[startidx:startidx+self.threshold_length]

        return waveform, label
    
    def get_value_counts(self, count=4):
        counts = [0] * 4

        for _,label in self.data:
            counts[label.item()] += 1

        return counts

# %%
class Model(nn.Module):
    def __init__(self, lstm_hidden_size=16, output_size=4):
        super().__init__()

        self.lstm_hidden_size = lstm_hidden_size

        self.conv1_layer = nn.Conv1d(1, 8, 20, 1)
        self.mp_1 = nn.MaxPool1d(5, 2)
        self.conv2_layer = nn.Conv1d(8, 16, 12, 1)
        self.mp_2 = nn.MaxPool1d(5, 2)
        self.conv3_layer = nn.Conv1d(16, 32, 8, 1)
        self.mp_3 = nn.MaxPool1d(5, 2)
        self.conv4_layer = nn.Conv1d(32, 32, 4, 1)
        self.mp_4 = nn.MaxPool1d(5, 2)

        self.d1 = nn.Dropout1d(0.2)
        self.d2 = nn.Dropout1d(0.2)
        self.d3 = nn.Dropout1d(0.2)
        self.d4 = nn.Dropout1d(0.2)
        # self.d4 = nn.Dropout1d(0.2)

        self.lstm = nn.LSTM(input_size=32, hidden_size=self.lstm_hidden_size, num_layers=2, batch_first=True, bidirectional=True, dropout=0.5)

        self.fc_dropout = nn.Dropout(0.5) 

        self.fullyconnected_layer = nn.Linear(2*self.lstm_hidden_size, output_size)

    def forward(self, x):
        x = x.unsqueeze(1)

        x = self.conv1_layer(x)
        x = F.relu(x)
        x = self.mp_1(x)
        x = self.d1(x)

        x = self.conv2_layer(x)
        x = F.relu(x)
        x = self.mp_2(x)
        x = self.d2(x)

        x = self.conv3_layer(x)
        x = F.relu(x)
        x = self.mp_3(x)
        x = self.d3(x)

        x = self.conv4_layer(x)
        x = F.relu(x)
        x = self.mp_4(x)
        x = self.d4(x)


        x = x.reshape(x.shape[0], x.shape[2], x.shape[1])

        x, _ = self.lstm(x)

        forward_out = x[:, -1, :self.lstm_hidden_size]
        backward_out = x[:, 0, self.lstm_hidden_size:]
        final_out = torch.cat([forward_out, backward_out], dim=1)

        x = self.fc_dropout(final_out)
        
        # x = x.reshape(x.shape[0], x.shape[2], x.shape[1])
        
        # x = F.avg_pool1d(x, x.shape[2])
        # x = x.squeeze(2)

        # x = self.fc_dropout(x)
        x = self.fullyconnected_layer(x)
        x = F.softmax(x, dim=1)

        return x
    
model = Model(lstm_hidden_size=32).to(device)

# %%
def plot_confusion_matrix(predictions, actuals, labelmap):
    """
    Plots a confusion matrix heatmap given the predictions and actual values.

    :param predictions: List of predicted categories.
    :param actuals: List of actual categories.
    """
    # Calculating the confusion matrix
    cm = confusion_matrix(actuals, predictions)

    labelmap = {x:y for y,x in labelmap.items()}

    # Converting the confusion matrix to fraction
    cm_fraction = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    # Creating a heatmap
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm_fraction, annot=True, fmt=".2f", cmap='Blues', xticklabels=[labelmap[i] for i in range(4)], yticklabels=[labelmap[i] for i in range(4)])
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix (as fraction)')
    plt.show()

# %%
def id(labels, n):
    return torch.eye(n, device=device)[labels]

def val_epoch(model,dataloader,criterion,confusion=False):
    totalloss = .0
    correct = 0
    total = 0

    model.eval()

    allp = []
    alll = []

    with torch.no_grad():
        for i, batch in enumerate(dataloader, 0):
            x, label = batch

            y = id(label, n=len(labelmap))

            yhat = model.forward(x)

            loss = criterion(yhat, y)

            _, predicted = torch.max(yhat.data, 1)

            total += yhat.shape[0]
            totalloss += loss.item()
            correct += (predicted == label).sum().item()

            if confusion:
                allp += [x.item() for x in predicted]
                alll += [x.item() for x in label]

    if confusion:
        plot_confusion_matrix(allp, alll, labelmap)

    return totalloss / total, correct / total

def train_epoch(model,dataloader,criterion,optimizer,confusion=False):
    totalloss = .0
    correct = 0
    total = 0

    model.train()
    for i,batch in enumerate(dataloader, 0):
        optimizer.zero_grad()

        x, label = batch

        y = id(label, n=len(labelmap))

        yhat = model.forward(x)

        loss = criterion(yhat, y)
        loss.backward()

        nn.utils.clip_grad_norm_(model.parameters(), max_norm=1)

        optimizer.step()

        _, predicted = torch.max(yhat.data, 1)

        total += yhat.shape[0]
        totalloss += loss.item()
        correct += (predicted == label).sum().item()

    return totalloss / total, correct / total

# val_epoch(model, trainloader, criterion, confusion=True)

# %%
batch_size = 128
n_epochs = 100
k = 10

splits = KFold(n_splits=k, shuffle=False)

dataset = WindowDataset(data, labelmap, device=device)


# normalise_val = np.mean([np.abs(x[0]).max() for x in data_train])

train_dataset = WindowDataset(data_train, labelmap, device=device)
test_dataset = WindowDataset(data_test, labelmap, device=device, eval=True)

trainloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
testloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %%
value_counts = train_dataset.get_value_counts()
weights = [sum(value_counts)/x for x in value_counts]
weights[labelmap['~']] = weights[labelmap['N']]

# %%
history = {'train_loss': [], 'test_loss': [],'train_acc':[],'test_acc':[]}

for fold, (train_idx,val_idx) in enumerate(splits.split(np.arange(len(dataset)))):

    print('Fold {}'.format(fold + 1))

    train_sampler = SubsetRandomSampler(train_idx)
    test_sampler = SubsetRandomSampler(val_idx)
    train_loader = DataLoader(dataset, batch_size=batch_size, sampler=train_sampler)
    test_loader = DataLoader(dataset, batch_size=batch_size, sampler=test_sampler)
    
    model = Model(lstm_hidden_size=32).to(device)
    optimizer = optim.Adam(model.parameters(), weight_decay=0.001)

    weight_tensor = torch.Tensor(weights).to(device)
    criterion = nn.CrossEntropyLoss(weight=weight_tensor)

    train_loss_list, test_loss_list, train_acc_list, test_acc_list = [], [], [], []

    for epoch in range(n_epochs):
        train_loss, train_acc=train_epoch(model,train_loader,criterion,optimizer)
        test_loss, test_acc=val_epoch(model,test_loader,criterion)

        train_loss_list.append(train_loss)
        train_acc_list.append(train_acc)
        test_loss_list.append(test_loss)
        test_acc_list.append(test_acc)

        train_loss = train_loss
        train_acc = train_acc * 100
        test_loss = test_loss
        test_acc = test_acc * 100
        
        if epoch % 10 == 9:
            print("Epoch:{}/{} AVG Training Loss:{:.3f} AVG Test Loss:{:.3f} AVG Training Acc {:.2f} % AVG Test Acc {:.2f} %".format(epoch + 1, n_epochs,train_loss,test_loss,train_acc,test_acc))

    history['train_loss'].append(train_loss_list)
    history['train_acc'].append(train_acc_list)
    history['test_loss'].append(test_loss_list)
    history['test_acc'].append(test_acc_list)
# Out:
# Fold 1
# Epoch:1/100 AVG Training Loss:0.032 AVG Test Loss:0.034 AVG Training Acc 35.44 % AVG Test Acc 9.61 %
# Epoch:11/100 AVG Training Loss:0.029 AVG Test Loss:0.030 AVG Training Acc 58.41 % AVG Test Acc 65.42 %
# Epoch:21/100 AVG Training Loss:0.028 AVG Test Loss:0.030 AVG Training Acc 60.05 % AVG Test Acc 62.72 %
# Epoch:31/100 AVG Training Loss:0.028 AVG Test Loss:0.030 AVG Training Acc 60.64 % AVG Test Acc 64.95 %
# Epoch:41/100 AVG Training Loss:0.028 AVG Test Loss:0.029 AVG Training Acc 63.90 % AVG Test Acc 67.64 %
# Epoch:51/100 AVG Training Loss:0.028 AVG Test Loss:0.029 AVG Training Acc 63.96 % AVG Test Acc 68.23 %
# Epoch:61/100 AVG Training Loss:0.028 AVG Test Loss:0.029 AVG Training Acc 64.36 % AVG Test Acc 68.23 %
# Epoch:71/100 AVG Training Loss:0.028 AVG Test Loss:0.028 AVG Training Acc 64.48 % AVG Test Acc 69.52 %
# Epoch:81/100 AVG Training Loss:0.027 AVG Test Loss:0.029 AVG Training Acc 63.35 % AVG Test Acc 69.05 %
# Epoch:91/100 AVG Training Loss:0.028 AVG Test Loss:0.029 AVG Training Acc 65.43 % AVG Test Acc 68.70 %
# Fold 2
# Epoch:1/100 AVG Training Loss:0.032 AVG Test Loss:0.036 AVG Training Acc 44.14 % AVG Test Acc 16.30 %
# Epoch:11/100 AVG Training Loss:0.029 AVG Test Loss:0.032 AVG Training Acc 59.10 % AVG Test Acc 63.19 %
# Epoch:21/100 AVG Training Loss:0.028 AVG Test Loss:0.031 AVG Training Acc 59.95 % AVG Test Acc 66.82 %
# Epoch:31/100 AVG Training Loss:0.028 AVG Test Loss:0.031 AVG Training Acc 62.42 % AVG Test Acc 64.95 %
# Epoch:41/100 AVG Training Loss:0.028 AVG Test Loss:0.029 AVG Training Acc 64.76 % AVG Test Acc 67.76 %
# Epoch:51/100 AVG Training Loss:0.028 AVG Test Loss:0.030 AVG Training Acc 64.48 % AVG Test Acc 67.64 %
# Epoch:61/100 AVG Training Loss:0.028 AVG Test Loss:0.030 AVG Training Acc 64.34 % AVG Test Acc 63.66 %
# Epoch:71/100 AVG Training Loss:0.028 AVG Test Loss:0.030 AVG Training Acc 62.59 % AVG Test Acc 61.08 %
# Epoch:81/100 AVG Training Loss:0.028 AVG Test Loss:0.030 AVG Training Acc 64.10 % AVG Test Acc 64.83 %
# Epoch:91/100 AVG Training Loss:0.028 AVG Test Loss:0.030 AVG Training Acc 65.95 % AVG Test Acc 64.95 %
# Fold 3
# Epoch:1/100 AVG Training Loss:0.032 AVG Test Loss:0.034 AVG Training Acc 35.67 % AVG Test Acc 10.43 %
# Epoch:11/100 AVG Training Loss:0.029 AVG Test Loss:0.032 AVG Training Acc 56.98 % AVG Test Acc 61.43 %
# Epoch:21/100 AVG Training Loss:0.029 AVG Test Loss:0.031 AVG Training Acc 60.53 % AVG Test Acc 61.90 %
# Epoch:31/100 AVG Training Loss:0.028 AVG Test Loss:0.030 AVG Training Acc 64.00 % AVG Test Acc 69.52 %
# Epoch:41/100 AVG Training Loss:0.028 AVG Test Loss:0.030 AVG Training Acc 62.41 % AVG Test Acc 66.94 %
# Epoch:51/100 AVG Training Loss:0.028 AVG Test Loss:0.030 AVG Training Acc 65.30 % AVG Test Acc 67.17 %
# Epoch:61/100 AVG Training Loss:0.028 AVG Test Loss:0.029 AVG Training Acc 64.29 % AVG Test Acc 69.28 %
# Epoch:71/100 AVG Training Loss:0.028 AVG Test Loss:0.029 AVG Training Acc 63.74 % AVG Test Acc 65.06 %
# Epoch:81/100 AVG Training Loss:0.028 AVG Test Loss:0.030 AVG Training Acc 65.81 % AVG Test Acc 68.46 %
# Epoch:91/100 AVG Training Loss:0.028 AVG Test Loss:0.029 AVG Training Acc 64.35 % AVG Test Acc 66.47 %
# Fold 4
# Epoch:1/100 AVG Training Loss:0.033 AVG Test Loss:0.033 AVG Training Acc 27.48 % AVG Test Acc 25.21 %
# Epoch:11/100 AVG Training Loss:0.029 AVG Test Loss:0.030 AVG Training Acc 56.42 % AVG Test Acc 62.72 %
# Epoch:21/100 AVG Training Loss:0.029 AVG Test Loss:0.029 AVG Training Acc 61.86 % AVG Test Acc 66.35 %
# Epoch:31/100 AVG Training Loss:0.028 AVG Test Loss:0.028 AVG Training Acc 62.89 % AVG Test Acc 69.64 %
# Epoch:41/100 AVG Training Loss:0.028 AVG Test Loss:0.028 AVG Training Acc 64.93 % AVG Test Acc 66.59 %
# Epoch:51/100 AVG Training Loss:0.028 AVG Test Loss:0.028 AVG Training Acc 64.94 % AVG Test Acc 69.28 %
# Epoch:61/100 AVG Training Loss:0.028 AVG Test Loss:0.028 AVG Training Acc 63.83 % AVG Test Acc 70.69 %
# Epoch:71/100 AVG Training Loss:0.028 AVG Test Loss:0.028 AVG Training Acc 62.74 % AVG Test Acc 67.29 %
# Epoch:81/100 AVG Training Loss:0.028 AVG Test Loss:0.027 AVG Training Acc 64.83 % AVG Test Acc 69.75 %
# Epoch:91/100 AVG Training Loss:0.028 AVG Test Loss:0.028 AVG Training Acc 65.62 % AVG Test Acc 69.17 %
# Fold 5
# Epoch:1/100 AVG Training Loss:0.033 AVG Test Loss:0.032 AVG Training Acc 18.38 % AVG Test Acc 7.85 %
# Epoch:11/100 AVG Training Loss:0.029 AVG Test Loss:0.029 AVG Training Acc 55.79 % AVG Test Acc 57.44 %
# Epoch:21/100 AVG Training Loss:0.029 AVG Test Loss:0.028 AVG Training Acc 60.14 % AVG Test Acc 65.30 %
# Epoch:31/100 AVG Training Loss:0.028 AVG Test Loss:0.028 AVG Training Acc 62.51 % AVG Test Acc 63.66 %
# Epoch:41/100 AVG Training Loss:0.028 AVG Test Loss:0.028 AVG Training Acc 62.28 % AVG Test Acc 64.36 %
# Epoch:51/100 AVG Training Loss:0.028 AVG Test Loss:0.028 AVG Training Acc 64.85 % AVG Test Acc 65.53 %
# Epoch:61/100 AVG Training Loss:0.028 AVG Test Loss:0.027 AVG Training Acc 63.44 % AVG Test Acc 68.82 %
# Epoch:71/100 AVG Training Loss:0.028 AVG Test Loss:0.028 AVG Training Acc 65.24 % AVG Test Acc 67.17 %
# Epoch:81/100 AVG Training Loss:0.028 AVG Test Loss:0.028 AVG Training Acc 62.98 % AVG Test Acc 68.58 %
# Epoch:91/100 AVG Training Loss:0.028 AVG Test Loss:0.028 AVG Training Acc 63.99 % AVG Test Acc 68.23 %
# Fold 6
# Epoch:1/100 AVG Training Loss:0.033 AVG Test Loss:0.030 AVG Training Acc 30.75 % AVG Test Acc 5.63 %
# Epoch:11/100 AVG Training Loss:0.029 AVG Test Loss:0.027 AVG Training Acc 56.77 % AVG Test Acc 60.38 %
# Epoch:21/100 AVG Training Loss:0.029 AVG Test Loss:0.027 AVG Training Acc 59.04 % AVG Test Acc 60.02 %
# Epoch:31/100 AVG Training Loss:0.029 AVG Test Loss:0.028 AVG Training Acc 60.56 % AVG Test Acc 61.55 %
# Epoch:41/100 AVG Training Loss:0.029 AVG Test Loss:0.027 AVG Training Acc 60.86 % AVG Test Acc 61.08 %
# Epoch:51/100 AVG Training Loss:0.029 AVG Test Loss:0.027 AVG Training Acc 60.81 % AVG Test Acc 62.60 %
# Epoch:61/100 AVG Training Loss:0.029 AVG Test Loss:0.027 AVG Training Acc 62.24 % AVG Test Acc 63.19 %
# Epoch:71/100 AVG Training Loss:0.028 AVG Test Loss:0.027 AVG Training Acc 62.75 % AVG Test Acc 64.48 %
# Epoch:81/100 AVG Training Loss:0.028 AVG Test Loss:0.027 AVG Training Acc 64.04 % AVG Test Acc 65.77 %
# Epoch:91/100 AVG Training Loss:0.028 AVG Test Loss:0.027 AVG Training Acc 63.48 % AVG Test Acc 64.60 %
# Fold 7
# Epoch:1/100 AVG Training Loss:0.033 AVG Test Loss:0.032 AVG Training Acc 14.88 % AVG Test Acc 6.92 %
# Epoch:11/100 AVG Training Loss:0.029 AVG Test Loss:0.029 AVG Training Acc 58.24 % AVG Test Acc 61.90 %
# Epoch:21/100 AVG Training Loss:0.029 AVG Test Loss:0.029 AVG Training Acc 61.20 % AVG Test Acc 62.25 %
# Epoch:31/100 AVG Training Loss:0.028 AVG Test Loss:0.029 AVG Training Acc 64.14 % AVG Test Acc 66.35 %
# Epoch:41/100 AVG Training Loss:0.028 AVG Test Loss:0.028 AVG Training Acc 62.80 % AVG Test Acc 62.02 %
# Epoch:51/100 AVG Training Loss:0.028 AVG Test Loss:0.028 AVG Training Acc 63.86 % AVG Test Acc 65.65 %
# Epoch:61/100 AVG Training Loss:0.028 AVG Test Loss:0.028 AVG Training Acc 64.91 % AVG Test Acc 67.88 %
# Epoch:71/100 AVG Training Loss:0.028 AVG Test Loss:0.029 AVG Training Acc 64.09 % AVG Test Acc 64.13 %
# Epoch:81/100 AVG Training Loss:0.028 AVG Test Loss:0.028 AVG Training Acc 65.84 % AVG Test Acc 67.41 %
# Epoch:91/100 AVG Training Loss:0.028 AVG Test Loss:0.029 AVG Training Acc 66.45 % AVG Test Acc 67.29 %
# Fold 8
# Epoch:1/100 AVG Training Loss:0.032 AVG Test Loss:0.033 AVG Training Acc 21.09 % AVG Test Acc 7.85 %
# Epoch:11/100 AVG Training Loss:0.029 AVG Test Loss:0.030 AVG Training Acc 58.78 % AVG Test Acc 60.26 %
# Epoch:21/100 AVG Training Loss:0.029 AVG Test Loss:0.031 AVG Training Acc 60.30 % AVG Test Acc 59.91 %
# Epoch:31/100 AVG Training Loss:0.029 AVG Test Loss:0.031 AVG Training Acc 59.23 % AVG Test Acc 61.08 %
# Epoch:41/100 AVG Training Loss:0.028 AVG Test Loss:0.030 AVG Training Acc 61.85 % AVG Test Acc 65.42 %
# Epoch:51/100 AVG Training Loss:0.028 AVG Test Loss:0.030 AVG Training Acc 62.91 % AVG Test Acc 64.01 %
# Epoch:61/100 AVG Training Loss:0.028 AVG Test Loss:0.030 AVG Training Acc 61.97 % AVG Test Acc 63.07 %
# Epoch:71/100 AVG Training Loss:0.028 AVG Test Loss:0.030 AVG Training Acc 63.15 % AVG Test Acc 65.18 %
# Epoch:81/100 AVG Training Loss:0.028 AVG Test Loss:0.029 AVG Training Acc 64.35 % AVG Test Acc 62.95 %
# Epoch:91/100 AVG Training Loss:0.028 AVG Test Loss:0.030 AVG Training Acc 64.25 % AVG Test Acc 65.06 %
# Fold 9
# Epoch:1/100 AVG Training Loss:0.032 AVG Test Loss:0.035 AVG Training Acc 24.99 % AVG Test Acc 25.82 %
# Epoch:11/100 AVG Training Loss:0.029 AVG Test Loss:0.033 AVG Training Acc 60.94 % AVG Test Acc 59.62 %
# Epoch:21/100 AVG Training Loss:0.028 AVG Test Loss:0.031 AVG Training Acc 61.40 % AVG Test Acc 62.68 %
# Epoch:31/100 AVG Training Loss:0.028 AVG Test Loss:0.031 AVG Training Acc 62.58 % AVG Test Acc 64.67 %
# Epoch:41/100 AVG Training Loss:0.028 AVG Test Loss:0.030 AVG Training Acc 62.86 % AVG Test Acc 66.55 %
# Epoch:51/100 AVG Training Loss:0.028 AVG Test Loss:0.031 AVG Training Acc 63.29 % AVG Test Acc 64.32 %
# Epoch:61/100 AVG Training Loss:0.028 AVG Test Loss:0.031 AVG Training Acc 64.25 % AVG Test Acc 59.98 %
# Epoch:71/100 AVG Training Loss:0.028 AVG Test Loss:0.030 AVG Training Acc 64.86 % AVG Test Acc 65.14 %
# Epoch:81/100 AVG Training Loss:0.028 AVG Test Loss:0.031 AVG Training Acc 64.60 % AVG Test Acc 66.43 %
# Epoch:91/100 AVG Training Loss:0.027 AVG Test Loss:0.030 AVG Training Acc 65.78 % AVG Test Acc 66.55 %
# Fold 10
# Epoch:1/100 AVG Training Loss:0.032 AVG Test Loss:0.036 AVG Training Acc 28.99 % AVG Test Acc 31.46 %
# Epoch:11/100 AVG Training Loss:0.029 AVG Test Loss:0.033 AVG Training Acc 59.59 % AVG Test Acc 57.63 %
# Epoch:21/100 AVG Training Loss:0.028 AVG Test Loss:0.033 AVG Training Acc 62.47 % AVG Test Acc 59.62 %
# Epoch:31/100 AVG Training Loss:0.028 AVG Test Loss:0.032 AVG Training Acc 63.25 % AVG Test Acc 58.92 %
# Epoch:41/100 AVG Training Loss:0.028 AVG Test Loss:0.034 AVG Training Acc 65.10 % AVG Test Acc 61.38 %
# Epoch:51/100 AVG Training Loss:0.028 AVG Test Loss:0.032 AVG Training Acc 64.06 % AVG Test Acc 60.68 %
# Epoch:61/100 AVG Training Loss:0.027 AVG Test Loss:0.031 AVG Training Acc 64.21 % AVG Test Acc 59.86 %
# Epoch:71/100 AVG Training Loss:0.027 AVG Test Loss:0.032 AVG Training Acc 65.66 % AVG Test Acc 62.68 %
# Epoch:81/100 AVG Training Loss:0.028 AVG Test Loss:0.032 AVG Training Acc 64.77 % AVG Test Acc 63.73 %
# Epoch:91/100 AVG Training Loss:0.027 AVG Test Loss:0.033 AVG Training Acc 65.72 % AVG Test Acc 62.91 %

# %%
def mean(ls):
    return sum(ls) / len(ls)

# %%
print(f'Overall results of {k} fold cross-validation')
print(f'Train: Average loss {mean([x[-1] for x in history["train_loss"]])}, average accuracy {mean([x[-1] for x in history["train_acc"]]) * 100}')
print(f'Test: Average loss {mean([x[-1] for x in history["test_loss"]])}, average accuracy {mean([x[-1] for x in history["test_acc"]]) * 100}')
# Out:
# Overall results of 10 fold cross-validation
# Train: Average loss 0.027698166791889127, average accuracy 64.95206057036359
# Test: Average loss 0.029194333609523775, average accuracy 65.97060086191239

# %%
fig, ax1 = plt.subplots()

# Plotting 'loss' on the left y-axis
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color='tab:red')
ax1.plot([x for x in history['train_loss'][0]], label='Train Loss', color='tab:red')
ax1.plot([x for x in history['test_loss'][0]], label='Test Loss', color='tab:orange')
ax1.tick_params(axis='y', labelcolor='tab:red')
ax1.legend(loc='upper left')

# Creating a second y-axis for 'accuracy'
ax2 = ax1.twinx()
ax2.set_ylabel('Accuracy', color='tab:blue')
ax2.plot([x for x in history['train_acc'][0]], label='Train Accuracy', color='tab:blue')
ax2.plot([x for x in history['test_acc'][0]], label='Test Accuracy', color='tab:green')
ax2.tick_params(axis='y', labelcolor='tab:blue')
ax2.legend(loc='upper right')

# Show the plot
plt.show()

# %%
print(f'best model test performance {max([x[1][1] for x in losses])}')
# Out:
# best model test performance 0.6828839390386869
