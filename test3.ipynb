# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt

# %%
waveform = scipy.io.loadmat('A1000.mat')['val']

# %%
waveform.shape
# Out:
# (12, 12000)

# %%
waveform.transpose()[:,:500].shape
# Out:
# (12000, 12)

# %%
plt.plot(waveform.transpose()[:2000,1])
