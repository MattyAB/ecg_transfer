# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt

# %%
waveform = scipy.io.loadmat('E00001.mat')['val']

# %%
waveform.shape
# Out:
# (12, 5000)

# %%
waveform.transpose()[:,:500].shape
# Out:
# (5000, 12)

# %%
plt.plot(waveform.transpose()[:500,1])
